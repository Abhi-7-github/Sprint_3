# %% [markdown]
# # Jupyter Workspace Proof
#
# This notebook exists to prove correct Jupyter workspace usage for Sprint 3.
#
# - It should live in the project folder: Sprint_3/notebooks/
# - Launch Jupyter from the Sprint_3 directory so relative paths work.

# %%
import os
print("Current working directory (cwd):", os.getcwd())
print("Notebook file is inside: Sprint_3/notebooks/")
# Out:
# Current working directory (cwd): C:\Users\hp\Desktop\Sprint_3
# Notebook file is inside: Sprint_3/notebooks/
